# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# importing required libraries
import numpy as np
import pandas as pd
import pickle # saving and loading trained model
from os import path

# importing required libraries for normalizing data
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# importing library for plotting
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

#import tensorflow as tf
from tensorflow.keras.utils import to_categorical

from keras.layers import Dense, LSTM, MaxPool1D, Flatten, Dropout, Bidirectional # importing dense layer
from keras.models import Sequential #importing Sequential layer
from keras.layers import Input
from keras.models import Model
# representation of model layers
from tensorflow.keras.utils import plot_model

# %%
# Generated Train + Regular Test
data= pd.read_csv('/content/drive/MyDrive/DLC-IDS/Datasets/train_merged_U2R_sdv.csv')
data_test = pd.read_csv('/content/drive/MyDrive/DLC-IDS/Datasets/test_merged_U2R.csv')

# %%
# number of attack labels for train data
data['label'].value_counts()
# Out:
# label
# normal    67343
# Other     58578
# U2R       50052
# Name: count, dtype: int64

# %%
# number of attack labels for test data
data_test['label'].value_counts()
# Out:
# label
# Other     12766
# normal     9711
# U2R          67
# Name: count, dtype: int64

# %%
# using standard scaler for normalizing
std_scaler = StandardScaler()
def standardization(df,col):
    for i in col:
        arr = df[i]
        arr = np.array(arr)
        df[i] = std_scaler.fit_transform(arr.reshape(len(arr),1))
    return df

numeric_col = data.select_dtypes(include='number').columns
data = standardization(data,numeric_col)
numeric_col = data_test.select_dtypes(include='number').columns
data_test = standardization(data_test,numeric_col)

# %%
data['label'].replace(('normal', 'U2R', 'Other'), (2, 1, 0), inplace=True)
print(data.shape)
data
# Out:
# <ipython-input-7-725e038a0faa>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['label'].replace(('normal', 'U2R', 'Other'), (2, 1, 0), inplace=True)
# <ipython-input-7-725e038a0faa>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['label'].replace(('normal', 'U2R', 'Other'), (2, 1, 0), inplace=True)
# (175973, 42)
#         duration protocol_type    service  flag  src_bytes  dst_bytes  \
# 0      -0.096681           tcp   ftp_data    SF  -0.006471  -0.004164
# 1      -0.096681           udp      other    SF  -0.006540  -0.004164
# 2      -0.096681           tcp    private    S0  -0.006570  -0.004164
# 3      -0.096681           tcp       http    SF  -0.006523  -0.001767
# 4      -0.096681           tcp       http    SF  -0.006530  -0.004040
# ...          ...           ...        ...   ...        ...        ...
# 175968 -0.090339           tcp      eco_i    S0  -0.006568  -0.003595
# 175969 -0.051380           tcp  hostnames   REJ  -0.006570  -0.004164
# 175970 -0.096681           tcp       http   REJ  -0.006570  -0.004164
# 175971 -0.059534           tcp       http  RSTR  -0.006570  -0.004164
# 175972 -0.096681           tcp       smtp  RSTR  -0.006570  -0.004164
#
#             land  wrong_fragment    urgent       hot  ...  dst_host_srv_count  \
# 0      -0.013695       -0.091696 -0.007586 -0.356667  ...           -0.552160
# 1      -0.013695       -0.091696 -0.007586 -0.356667  ...           -0.777185
# 2      -0.013695       -0.091696 -0.007586 -0.356667  ...           -0.542784
# 3      -0.013695       -0.091696 -0.007586 -0.356667  ...            1.604328
# 4      -0.013695       -0.091696 -0.007586 -0.356667  ...            1.604328
# ...          ...             ...       ...       ...  ...                 ...
# 175968 -0.013695       11.450517 -0.007586  2.376388  ...           -0.345887
# 175969 -0.013695       -0.091696 -0.007586 -0.174463  ...           -0.786561
# 175970 -0.013695       -0.091696 -0.007586 -0.174463  ...           -0.767809
# 175971 -0.013695       -0.091696 -0.007586 -0.174463  ...           -0.786561
# 175972 -0.013695       -0.091696 -0.007586 -0.174463  ...           -0.786561
#
#         dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    -0.494047               -0.597168
# 1                    -0.874086                1.064044
# 2                    -0.650533               -0.538880
# 3                     1.361439               -0.684600
# 4                     1.361439               -0.684600
# ...                        ...                     ...
# 175968               -0.851730                0.189722
# 175969               -0.874086                2.229807
# 175970               -0.538757                0.102290
# 175971               -0.874086                2.229807
# 175972               -0.874086                2.229807
#
#         dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                          0.194273                    -0.258787
# 1                          2.743639                    -0.258787
# 2                         -0.416139                    -0.258787
# 3                         -0.308419                     0.153351
# 4                         -0.416139                    -0.258787
# ...                             ...                          ...
# 175968                    -0.416139                    -0.258787
# 175969                    -0.416139                    -0.258787
# 175970                    -0.416139                     0.874593
# 175971                    -0.416139                    -0.258787
# 175972                    -0.416139                    -0.258787
#
#         dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  -0.935595                 -0.904661             -0.328263
# 1                  -0.935595                 -0.904661             -0.469367
# 2                   1.089816                  1.114531             -0.469367
# 3                  -0.874832                 -0.884469             -0.469367
# 4                  -0.935595                 -0.904661             -0.469367
# ...                      ...                       ...                   ...
# 175968              1.089816                  1.114531             -0.469367
# 175969              1.089816                  1.114531             -0.469367
# 175970              1.089816                  1.114531             -0.469367
# 175971              1.089816                  1.114531             -0.469367
# 175972              1.089816                  1.114531             -0.469367
#
#         dst_host_srv_rerror_rate  label
# 0                      -0.446919      2
# 1                      -0.446919      2
# 2                      -0.446919      0
# 3                      -0.419343      2
# 4                      -0.446919      2
# ...                          ...    ...
# 175968                 -0.446919      1
# 175969                 -0.446919      1
# 175970                 -0.446919      1
# 175971                 -0.446919      1
# 175972                 -0.446919      1
#
# [175973 rows x 42 columns]

# %%
data['label'].replace(('normal', 'U2R', 'Other'), (2, 1, 0), inplace=True)
print(data.shape)
data
# Out:
# <ipython-input-8-725e038a0faa>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['label'].replace(('normal', 'U2R', 'Other'), (2, 1, 0), inplace=True)
# (175973, 42)
#         duration protocol_type    service  flag  src_bytes  dst_bytes  \
# 0      -0.096681           tcp   ftp_data    SF  -0.006471  -0.004164
# 1      -0.096681           udp      other    SF  -0.006540  -0.004164
# 2      -0.096681           tcp    private    S0  -0.006570  -0.004164
# 3      -0.096681           tcp       http    SF  -0.006523  -0.001767
# 4      -0.096681           tcp       http    SF  -0.006530  -0.004040
# ...          ...           ...        ...   ...        ...        ...
# 175968 -0.090339           tcp      eco_i    S0  -0.006568  -0.003595
# 175969 -0.051380           tcp  hostnames   REJ  -0.006570  -0.004164
# 175970 -0.096681           tcp       http   REJ  -0.006570  -0.004164
# 175971 -0.059534           tcp       http  RSTR  -0.006570  -0.004164
# 175972 -0.096681           tcp       smtp  RSTR  -0.006570  -0.004164
#
#             land  wrong_fragment    urgent       hot  ...  dst_host_srv_count  \
# 0      -0.013695       -0.091696 -0.007586 -0.356667  ...           -0.552160
# 1      -0.013695       -0.091696 -0.007586 -0.356667  ...           -0.777185
# 2      -0.013695       -0.091696 -0.007586 -0.356667  ...           -0.542784
# 3      -0.013695       -0.091696 -0.007586 -0.356667  ...            1.604328
# 4      -0.013695       -0.091696 -0.007586 -0.356667  ...            1.604328
# ...          ...             ...       ...       ...  ...                 ...
# 175968 -0.013695       11.450517 -0.007586  2.376388  ...           -0.345887
# 175969 -0.013695       -0.091696 -0.007586 -0.174463  ...           -0.786561
# 175970 -0.013695       -0.091696 -0.007586 -0.174463  ...           -0.767809
# 175971 -0.013695       -0.091696 -0.007586 -0.174463  ...           -0.786561
# 175972 -0.013695       -0.091696 -0.007586 -0.174463  ...           -0.786561
#
#         dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    -0.494047               -0.597168
# 1                    -0.874086                1.064044
# 2                    -0.650533               -0.538880
# 3                     1.361439               -0.684600
# 4                     1.361439               -0.684600
# ...                        ...                     ...
# 175968               -0.851730                0.189722
# 175969               -0.874086                2.229807
# 175970               -0.538757                0.102290
# 175971               -0.874086                2.229807
# 175972               -0.874086                2.229807
#
#         dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                          0.194273                    -0.258787
# 1                          2.743639                    -0.258787
# 2                         -0.416139                    -0.258787
# 3                         -0.308419                     0.153351
# 4                         -0.416139                    -0.258787
# ...                             ...                          ...
# 175968                    -0.416139                    -0.258787
# 175969                    -0.416139                    -0.258787
# 175970                    -0.416139                     0.874593
# 175971                    -0.416139                    -0.258787
# 175972                    -0.416139                    -0.258787
#
#         dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  -0.935595                 -0.904661             -0.328263
# 1                  -0.935595                 -0.904661             -0.469367
# 2                   1.089816                  1.114531             -0.469367
# 3                  -0.874832                 -0.884469             -0.469367
# 4                  -0.935595                 -0.904661             -0.469367
# ...                      ...                       ...                   ...
# 175968              1.089816                  1.114531             -0.469367
# 175969              1.089816                  1.114531             -0.469367
# 175970              1.089816                  1.114531             -0.469367
# 175971              1.089816                  1.114531             -0.469367
# 175972              1.089816                  1.114531             -0.469367
#
#         dst_host_srv_rerror_rate  label
# 0                      -0.446919      2
# 1                      -0.446919      2
# 2                      -0.446919      0
# 3                      -0.419343      2
# 4                      -0.446919      2
# ...                          ...    ...
# 175968                 -0.446919      1
# 175969                 -0.446919      1
# 175970                 -0.446919      1
# 175971                 -0.446919      1
# 175972                 -0.446919      1
#
# [175973 rows x 42 columns]

# %%
y_data= data['label']
X_data= data.drop(labels=['label'], axis=1)

print('X_train has shape:',X_data.shape,'\ny_train has shape:',y_data.shape)
# Out:
# X_train has shape: (175973, 41)
# y_train has shape: (175973,)

# %%
# one-hot-encoding categorical columns
data = pd.get_dummies(data,columns=['protocol_type','service','flag'],prefix="",prefix_sep="")
print(data.shape)
# Out:
# (175973, 123)

# %%
# one-hot-encoding categorical columns
data_test = pd.get_dummies(data_test,columns=['protocol_type','service','flag'],prefix="",prefix_sep="")
print(data_test.shape)
# Out:
# (22544, 117)

# %%
def drop_missing_columns(df1, df2):
    missing_columns = set(df1.columns) - set(df2.columns)
    print(list(missing_columns))
    return df1.drop(missing_columns, axis=1)

data = drop_missing_columns(data, data_test)
data_test = drop_missing_columns(data_test, data)
data
# Out:
# ['http_2784', 'http_8001', 'urh_i', 'aol', 'red_i', 'harvest']
# []
#         duration  src_bytes  dst_bytes      land  wrong_fragment    urgent  \
# 0      -0.096681  -0.006471  -0.004164 -0.013695       -0.091696 -0.007586
# 1      -0.096681  -0.006540  -0.004164 -0.013695       -0.091696 -0.007586
# 2      -0.096681  -0.006570  -0.004164 -0.013695       -0.091696 -0.007586
# 3      -0.096681  -0.006523  -0.001767 -0.013695       -0.091696 -0.007586
# 4      -0.096681  -0.006530  -0.004040 -0.013695       -0.091696 -0.007586
# ...          ...        ...        ...       ...             ...       ...
# 175968 -0.090339  -0.006568  -0.003595 -0.013695       11.450517 -0.007586
# 175969 -0.051380  -0.006570  -0.004164 -0.013695       -0.091696 -0.007586
# 175970 -0.096681  -0.006570  -0.004164 -0.013695       -0.091696 -0.007586
# 175971 -0.059534  -0.006570  -0.004164 -0.013695       -0.091696 -0.007586
# 175972 -0.096681  -0.006570  -0.004164 -0.013695       -0.091696 -0.007586
#
#              hot  num_failed_logins  logged_in  num_compromised  ...    REJ  \
# 0      -0.356667          -0.027101  -0.638491        -0.244833  ...  False
# 1      -0.356667          -0.027101  -0.638491        -0.244833  ...  False
# 2      -0.356667          -0.027101  -0.638491        -0.244833  ...  False
# 3      -0.356667          -0.027101   1.566192        -0.244833  ...  False
# 4      -0.356667          -0.027101   1.566192        -0.244833  ...  False
# ...          ...                ...        ...              ...  ...    ...
# 175968  2.376388          -0.027101   1.566192         0.235013  ...  False
# 175969 -0.174463          -0.027101  -0.638491        -0.244833  ...   True
# 175970 -0.174463          -0.027101  -0.638491         0.022773  ...   True
# 175971 -0.174463          -0.027101  -0.638491        -0.217150  ...  False
# 175972 -0.174463          -0.027101  -0.638491        -0.244833  ...  False
#
#          RSTO  RSTOS0   RSTR     S0     S1     S2     S3     SF     SH
# 0       False   False  False  False  False  False  False   True  False
# 1       False   False  False  False  False  False  False   True  False
# 2       False   False  False   True  False  False  False  False  False
# 3       False   False  False  False  False  False  False   True  False
# 4       False   False  False  False  False  False  False   True  False
# ...       ...     ...    ...    ...    ...    ...    ...    ...    ...
# 175968  False   False  False   True  False  False  False  False  False
# 175969  False   False  False  False  False  False  False  False  False
# 175970  False   False  False  False  False  False  False  False  False
# 175971  False   False   True  False  False  False  False  False  False
# 175972  False   False   True  False  False  False  False  False  False
#
# [175973 rows x 117 columns]

# %%
data_test
# Out:
#        duration  src_bytes  dst_bytes      land  wrong_fragment    urgent  \
# 0     -0.155534  -0.021988  -0.096896 -0.017624       -0.059104 -0.019459
# 1     -0.155534  -0.021988  -0.096896 -0.017624       -0.059104 -0.019459
# 2     -0.154113   0.005473  -0.096896 -0.017624       -0.059104 -0.019459
# 3     -0.155534  -0.021946  -0.096896 -0.017624       -0.059104 -0.019459
# 4     -0.154823  -0.021988  -0.096189 -0.017624       -0.059104 -0.019459
# ...         ...        ...        ...       ...             ...       ...
# 22539 -0.155534  -0.020309  -0.081202 -0.017624       -0.059104 -0.019459
# 22540 -0.155534  -0.021318  -0.052690 -0.017624       -0.059104 -0.019459
# 22541 -0.155534   0.093373   0.294926 -0.017624       -0.059104 -0.019459
# 22542 -0.155534  -0.021899  -0.094917 -0.017624       -0.059104 -0.019459
# 22543 -0.155534  -0.021988  -0.096896 -0.017624       -0.059104 -0.019459
#
#             hot  num_failed_logins  logged_in  num_compromised  ...    REJ  \
# 0     -0.113521          -0.143999  -0.890373        -0.016494  ...   True
# 1     -0.113521          -0.143999  -0.890373        -0.016494  ...   True
# 2     -0.113521          -0.143999  -0.890373        -0.016494  ...  False
# 3     -0.113521          -0.143999  -0.890373        -0.016494  ...  False
# 4     -0.113521          -0.143999  -0.890373        -0.016494  ...  False
# ...         ...                ...        ...              ...  ...    ...
# 22539 -0.113521          -0.143999   1.123125        -0.016494  ...  False
# 22540 -0.113521          -0.143999   1.123125        -0.016494  ...  False
# 22541  2.040705          -0.143999   1.123125         0.121069  ...  False
# 22542 -0.113521          -0.143999  -0.890373        -0.016494  ...  False
# 22543 -0.113521          -0.143999  -0.890373        -0.016494  ...   True
#
#         RSTO  RSTOS0   RSTR     S0     S1     S2     S3     SF     SH
# 0      False   False  False  False  False  False  False  False  False
# 1      False   False  False  False  False  False  False  False  False
# 2      False   False  False  False  False  False  False   True  False
# 3      False   False  False  False  False  False  False   True  False
# 4       True   False  False  False  False  False  False  False  False
# ...      ...     ...    ...    ...    ...    ...    ...    ...    ...
# 22539  False   False  False  False  False  False  False   True  False
# 22540  False   False  False  False  False  False  False   True  False
# 22541  False   False  False  False  False  False  False   True  False
# 22542  False   False  False  False  False  False  False   True  False
# 22543  False   False  False  False  False  False  False  False  False
#
# [22544 rows x 117 columns]

# %%
y_data= data['label']
X_data= data.drop(labels=['label'], axis=1)

print('X_train has shape:',X_data.shape,'\ny_train has shape:',y_data.shape)
# Out:
# X_train has shape: (175973, 116)
# y_train has shape: (175973,)

# %%
y_data_test= data_test['label']
X_data_test= data_test.drop(labels=['label'], axis=1)

print('X_test has shape:',X_data_test.shape,'\n y_test has shape:',y_data_test.shape)
# Out:
# X_test has shape: (22544, 116)
#  y_test has shape: (22544,)

# %%
from sklearn.preprocessing import LabelBinarizer
y_data = LabelBinarizer().fit_transform(y_data)

X_data=np.array(X_data)
y_data=np.array(y_data)

# %%
y_data_test = LabelBinarizer().fit_transform(y_data_test)

X_data_test=np.array(X_data_test)
y_data_test=np.array(y_data_test)

# %%
X_train = X_data
X_test = X_data_test
y_train = y_data
y_test  = y_data_test
print(X_train.shape,'\n',X_test.shape)
#print(X_train)
# Out:
# (175973, 116)
#  (22544, 116)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, ( X_train.shape[0], 1 , X_train.shape[1] ))
X_test = np.reshape(X_test, ( X_test.shape[0], 1,  X_test.shape[1] ))

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (175973, 1, 116)
# (22544, 1, 116)

# %%
pip install keras-self-attention
# Out:
# Collecting keras-self-attention
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras-self-attention) (2.0.2)
# Building wheels for collected packages: keras-self-attention
#   Building wheel for keras-self-attention (setup.py) ... done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18895 sha256=65306d18e4900688b9cf4037cce6e6abacbebc43354643cef525315ca600bdcc
#   Stored in directory: /root/.cache/pip/wheels/46/f9/96/709295c836133071c12a300729fed4027757f889c01695feea
# Successfully built keras-self-attention
# Installing collected packages: keras-self-attention
# Successfully installed keras-self-attention-0.51.0

# %%
pip install attention
# Out:
# Collecting attention
#   Downloading attention-5.0.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.11/dist-packages (from attention) (2.0.2)
# Requirement already satisfied: tensorflow>=2.1 in /usr/local/lib/python3.11/dist-packages (from attention) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (4.13.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow>=2.1->attention) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.1->attention) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.1->attention) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.1->attention) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.1->attention) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.1->attention) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.1->attention) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.1->attention) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.1->attention) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.1->attention) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.1->attention) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow>=2.1->attention) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.1->attention) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.1->attention) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow>=2.1->attention) (0.1.2)
# Downloading attention-5.0.0-py3-none-any.whl (9.0 kB)
# Installing collected packages: attention
# Successfully installed attention-5.0.0

# %%
# LSTM MODEL + ATTENTION

import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout,Bidirectional,Masking,LSTM
from keras_self_attention import SeqSelfAttention
from attention import Attention

model = Sequential() # initializing model
model.add(LSTM(64,return_sequences=True,input_shape = (1, X_train.shape[2])))
model.add(Dropout(0.5))
model.add(LSTM(64,return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64,return_sequences=True))
#model.add(Attention(units=64))
model.add(SeqSelfAttention(attention_activation='sigmoid'))
model.add(Flatten())
model.add(Dense(units=50))
# output layer with softmax activation
model.add(Dense(units=3,activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
import tensorflow as tf
#from tensorflow.keras.optimizers import Adam

#optimizer = Adam(learning_rate=0.001)

# defining loss function, optimizer, metrics and then compiling model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy',tf.keras.metrics.Precision(),tf.keras.metrics.Recall()])

# %%
# summary of model layers
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 1, 64)          │        46,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 1, 64)          │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 1, 64)          │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ seq_self_attention              │ (None, 1, 64)          │         4,161 │
# │ (SeqSelfAttention)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 50)             │         3,250 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           153 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 119,948 (468.55 KB)
#  Trainable params: 119,948 (468.55 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Visualize the model

from keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True, expand_nested=True)

# %%
X_train = X_train.astype(float)
print(X_train.shape)
y_train = y_train.astype(float)
print(y_train.shape)
# Out:
# (175973, 1, 116)
# (175973, 3)

# %%
# training the model on training dataset
history = model.fit(X_train, y_train, epochs=50, batch_size=5000,validation_split=0.2)
# Out:
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 33s 443ms/step - accuracy: 0.7167 - loss: 1.0435 - precision: 0.4164 - recall: 0.0202 - val_accuracy: 0.0000e+00 - val_loss: 1.3576 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.8246 - loss: 0.5023 - precision: 0.8536 - recall: 0.7669 - val_accuracy: 0.2293 - val_loss: 1.0595 - val_precision: 0.0163 - val_recall: 0.0105
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 228ms/step - accuracy: 0.9193 - loss: 0.2271 - precision: 0.9283 - recall: 0.9081 - val_accuracy: 0.9354 - val_loss: 0.1928 - val_precision: 0.9387 - val_recall: 0.9325
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 156ms/step - accuracy: 0.9664 - loss: 0.1155 - precision: 0.9675 - recall: 0.9654 - val_accuracy: 0.9633 - val_loss: 0.1201 - val_precision: 0.9658 - val_recall: 0.9623
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 226ms/step - accuracy: 0.9720 - loss: 0.0960 - precision: 0.9729 - recall: 0.9711 - val_accuracy: 0.9728 - val_loss: 0.0891 - val_precision: 0.9745 - val_recall: 0.9716
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 160ms/step - accuracy: 0.9751 - loss: 0.0877 - precision: 0.9758 - recall: 0.9745 - val_accuracy: 0.9778 - val_loss: 0.0712 - val_precision: 0.9793 - val_recall: 0.9772
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 204ms/step - accuracy: 0.9757 - loss: 0.0839 - precision: 0.9763 - recall: 0.9750 - val_accuracy: 0.9815 - val_loss: 0.0597 - val_precision: 0.9825 - val_recall: 0.9805
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.9777 - loss: 0.0777 - precision: 0.9782 - recall: 0.9770 - val_accuracy: 0.9840 - val_loss: 0.0504 - val_precision: 0.9851 - val_recall: 0.9835
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 195ms/step - accuracy: 0.9801 - loss: 0.0716 - precision: 0.9806 - recall: 0.9795 - val_accuracy: 0.9864 - val_loss: 0.0423 - val_precision: 0.9875 - val_recall: 0.9858
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 11s 220ms/step - accuracy: 0.9797 - loss: 0.0708 - precision: 0.9803 - recall: 0.9790 - val_accuracy: 0.9882 - val_loss: 0.0386 - val_precision: 0.9891 - val_recall: 0.9877
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - accuracy: 0.9806 - loss: 0.0677 - precision: 0.9812 - recall: 0.9801 - val_accuracy: 0.9896 - val_loss: 0.0337 - val_precision: 0.9904 - val_recall: 0.9892
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - accuracy: 0.9940 - loss: 0.0193 - precision: 0.9941 - recall: 0.9939 - val_accuracy: 0.9982 - val_loss: 0.0061 - val_precision: 0.9982 - val_recall: 0.9982
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 9s 151ms/step - accuracy: 0.9943 - loss: 0.0182 - precision: 0.9944 - recall: 0.9941 - val_accuracy: 0.9981 - val_loss: 0.0063 - val_precision: 0.9981 - val_recall: 0.9981
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 216ms/step - accuracy: 0.9946 - loss: 0.0184 - precision: 0.9947 - recall: 0.9945 - val_accuracy: 0.9981 - val_loss: 0.0063 - val_precision: 0.9982 - val_recall: 0.9981
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - accuracy: 0.9940 - loss: 0.0195 - precision: 0.9940 - recall: 0.9939 - val_accuracy: 0.9981 - val_loss: 0.0066 - val_precision: 0.9981 - val_recall: 0.9981
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 220ms/step - accuracy: 0.9944 - loss: 0.0187 - precision: 0.9944 - recall: 0.9943 - val_accuracy: 0.9979 - val_loss: 0.0068 - val_precision: 0.9979 - val_recall: 0.9978

# %%
X_test = X_test.astype(float)
y_test = y_test.astype(float)

# %%
# predicting target attribute on testing dataset
test_results = model.evaluate(X_test, y_test,verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')
# Out:
# 705/705 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.2578 - loss: 6.8147 - precision: 0.2673 - recall: 0.2405
# Test results - Loss: 6.7805023193359375 - Accuracy: 25.878283381462097%

# %%
results = model.evaluate(X_test, y_test,batch_size = 128)
# Out:
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2578 - loss: 6.8141 - precision: 0.2672 - recall: 0.2404

# %%
print(model.metrics_names)
print(results)
# Out:
# ['loss', 'compile_metrics']
# [6.780501365661621, 0.25878283381462097, 0.2694303095340729, 0.2418825477361679]

# %%
# # Plot of accuracy vs epoch for train and test dataset
# plt.plot(history.history['accuracy'])
# plt.plot(history.history['val_accuracy'])
# plt.title("Plot of accuracy vs epoch for train and test dataset")
# plt.ylabel('accuracy')
# plt.xlabel('epoch')
# plt.show()
pd.DataFrame(history.history)
pd.DataFrame(history.history)[['accuracy','val_accuracy']].plot()
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
# Out:
# Text(0.5, 0, 'Epochs')

# %%
# # Plot of loss vs epoch for train and test dataset
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title("Plot of loss vs epoch for train and test dataset")
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper right')
# plt.show()
pd.DataFrame(history.history)
pd.DataFrame(history.history)[['loss','val_loss']].plot()
plt.ylabel('Model Loss')
plt.xlabel('Epochs')
# Out:
# Text(0.5, 0, 'Epochs')

# %%
from sklearn.metrics import classification_report

y_predict = model.predict(X_test)
y_pred = y_predict.argmax(axis=-1)
y_test = y_test.argmax(axis = -1 )
report = classification_report(y_test, y_pred)
print(report)
print(y_pred)
df1 = pd.DataFrame(y_pred)
# saving the dataframe
df1.to_csv('/content/drive/MyDrive/DLC-IDS/Outputs/CU.csv', index = False)
# Out:
# 705/705 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.31      0.03      0.06     12766
#            1       0.00      0.96      0.01        67
#            2       0.70      0.55      0.62      9711
#
#     accuracy                           0.26     22544
#    macro avg       0.34      0.51      0.23     22544
# weighted avg       0.48      0.26      0.30     22544
#
# [1 1 1 ... 1 2 1]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)
# create a ConfusionMatrixDisplay object
cm_display = ConfusionMatrixDisplay(cm)
# plot the confusion matrix
print("Confusion Matrix:\n", cm)
cm_display.plot()
plt.show()
# Out:
# Confusion Matrix:
#  [[  390 10109  2267]
#  [    0    64     3]
#  [  865  3466  5380]]

# %%
import numpy as np


def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):

    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

# %%
from sklearn.metrics import confusion_matrix
plot_confusion_matrix(cm=confusion_matrix(y_test, y_pred),
                      normalize=False,
                      target_names=[],
                      title="Confusion Matrix")

# %%
from sklearn.metrics import confusion_matrix
plot_confusion_matrix(cm=confusion_matrix(y_test, y_pred),
                      normalize=True,
                      target_names=[],
                      title="Confusion Matrix")

# %%
model.save("NSL-KDD LSTM.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
