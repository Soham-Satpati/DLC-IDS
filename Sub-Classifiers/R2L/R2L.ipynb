# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# importing required libraries
import numpy as np
import pandas as pd
import pickle # saving and loading trained model
from os import path

# importing required libraries for normalizing data
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# importing library for plotting
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

#import tensorflow as tf
from tensorflow.keras.utils import to_categorical

from keras.layers import Dense, LSTM, MaxPool1D, Flatten, Dropout, Bidirectional # importing dense layer
from keras.models import Sequential #importing Sequential layer
from keras.layers import Input
from keras.models import Model
# representation of model layers
from tensorflow.keras.utils import plot_model

# %%
# Generated Train + Regular Test
data= pd.read_csv('/content/drive/MyDrive/DLC-IDS/Datasets/train_merged_R2L_sdv.csv')
data_test = pd.read_csv('/content/drive/MyDrive/DLC-IDS/Datasets/test_merged_R2L.csv')

# %%
# number of attack labels for train data
data['label'].value_counts()
# Out:
# label
# R2L       150995
# normal     67343
# Other      57635
# Name: count, dtype: int64

# %%
# number of attack labels for test data
data_test['label'].value_counts()
# Out:
# label
# Other     9948
# normal    9711
# R2L       2885
# Name: count, dtype: int64

# %%
# using standard scaler for normalizing
std_scaler = StandardScaler()
def standardization(df,col):
    for i in col:
        arr = df[i]
        arr = np.array(arr)
        df[i] = std_scaler.fit_transform(arr.reshape(len(arr),1))
    return df

numeric_col = data.select_dtypes(include='number').columns
data = standardization(data,numeric_col)
numeric_col = data_test.select_dtypes(include='number').columns
data_test = standardization(data_test,numeric_col)

# %%
data['label'].replace(('normal', 'R2L', 'Other'), (2, 1, 0), inplace=True)
print(data.shape)
data
# Out:
# <ipython-input-7-224bdf0c3be6>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['label'].replace(('normal', 'R2L', 'Other'), (2, 1, 0), inplace=True)
# <ipython-input-7-224bdf0c3be6>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['label'].replace(('normal', 'R2L', 'Other'), (2, 1, 0), inplace=True)
# (275973, 42)
#         duration protocol_type   service  flag  src_bytes  dst_bytes  \
# 0      -0.085055           tcp  ftp_data    SF  -0.005162  -0.003374
# 1      -0.085055           udp     other    SF  -0.005249  -0.003374
# 2      -0.085055           tcp   private    S0  -0.005286  -0.003374
# 3      -0.085055           tcp      http    SF  -0.005228  -0.000373
# 4      -0.085055           tcp      http    SF  -0.005236  -0.003219
# ...          ...           ...       ...   ...        ...        ...
# 275968 -0.085055           tcp  domain_u  RSTR  -0.005286  -0.003374
# 275969 -0.084489           tcp      smtp  RSTO  -0.005286  -0.003374
# 275970 -0.078828           tcp      http  RSTO  -0.005286  -0.003374
# 275971 -0.085055           tcp      http    S0  -0.005286  -0.003374
# 275972 -0.085055           tcp      http   REJ  -0.005286  -0.003367
#
#             land  wrong_fragment    urgent       hot  ...  dst_host_srv_count  \
# 0      -0.013051       -0.093843 -0.008736 -0.526994  ...           -0.358038
# 1      -0.013051       -0.093843 -0.008736 -0.526994  ...           -0.614839
# 2      -0.013051       -0.093843 -0.008736 -0.526994  ...           -0.347338
# 3      -0.013051       -0.093843 -0.008736 -0.526994  ...            2.102973
# 4      -0.013051       -0.093843 -0.008736 -0.526994  ...            2.102973
# ...          ...             ...       ...       ...  ...                 ...
# 275968 -0.013051       -0.093843 -0.008736  0.006270  ...           -0.625539
# 275969 -0.013051       -0.093843 -0.008736  1.472747  ...           -0.625539
# 275970 -0.013051       -0.093843 -0.008736 -0.127046  ...           -0.625539
# 275971 -0.013051       -0.093843 -0.008736 -0.393678  ...           -0.507838
# 275972 -0.013051       11.175976 -0.008736 -0.260362  ...           -0.475738
#
#         dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    -0.329593               -0.765769
# 1                    -0.730618                0.868059
# 2                    -0.494721               -0.708442
# 3                     1.628353               -0.851760
# 4                     1.628353               -0.851760
# ...                        ...                     ...
# 275968               -0.730618                0.552759
# 275969               -0.730618                2.014605
# 275970               -0.730618                2.014605
# 275971               -0.093696                0.208795
# 275972               -0.730618               -0.765769
#
#         dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                          0.283646                    -0.259759
# 1                          3.049429                    -0.259759
# 2                         -0.378584                    -0.259759
# 3                         -0.261720                     0.227770
# 4                         -0.378584                    -0.259759
# ...                             ...                          ...
# 275968                    -0.378584                    -0.259759
# 275969                    -0.378584                    -0.259759
# 275970                    -0.378584                    -0.259759
# 275971                    -0.378584                    -0.259759
# 275972                    -0.378584                    -0.259759
#
#         dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  -1.145549                 -1.081826             -0.360096
# 1                  -1.145549                 -1.081826             -0.496432
# 2                   0.891163                  0.932580             -0.496432
# 3                  -1.084447                 -1.061681             -0.496432
# 4                  -1.145549                 -1.081826             -0.496432
# ...                      ...                       ...                   ...
# 275968              0.891163                  0.932580             -0.496432
# 275969              0.891163                  0.932580             -0.496432
# 275970              0.891163                  0.932580              2.230282
# 275971              0.891163                  0.932580             -0.496432
# 275972              0.891163                  0.932580             -0.496432
#
#         dst_host_srv_rerror_rate  label
# 0                      -0.466505      2
# 1                      -0.466505      2
# 2                      -0.466505      0
# 3                      -0.439694      2
# 4                      -0.466505      2
# ...                          ...    ...
# 275968                 -0.466505      1
# 275969                 -0.466505      1
# 275970                 -0.466505      1
# 275971                 -0.466505      1
# 275972                 -0.466505      1
#
# [275973 rows x 42 columns]

# %%
data['label'].replace(('normal', 'R2L', 'Other'), (2, 1, 0), inplace=True)
print(data.shape)
data
# Out:
# <ipython-input-8-224bdf0c3be6>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['label'].replace(('normal', 'R2L', 'Other'), (2, 1, 0), inplace=True)
# (275973, 42)
#         duration protocol_type   service  flag  src_bytes  dst_bytes  \
# 0      -0.085055           tcp  ftp_data    SF  -0.005162  -0.003374
# 1      -0.085055           udp     other    SF  -0.005249  -0.003374
# 2      -0.085055           tcp   private    S0  -0.005286  -0.003374
# 3      -0.085055           tcp      http    SF  -0.005228  -0.000373
# 4      -0.085055           tcp      http    SF  -0.005236  -0.003219
# ...          ...           ...       ...   ...        ...        ...
# 275968 -0.085055           tcp  domain_u  RSTR  -0.005286  -0.003374
# 275969 -0.084489           tcp      smtp  RSTO  -0.005286  -0.003374
# 275970 -0.078828           tcp      http  RSTO  -0.005286  -0.003374
# 275971 -0.085055           tcp      http    S0  -0.005286  -0.003374
# 275972 -0.085055           tcp      http   REJ  -0.005286  -0.003367
#
#             land  wrong_fragment    urgent       hot  ...  dst_host_srv_count  \
# 0      -0.013051       -0.093843 -0.008736 -0.526994  ...           -0.358038
# 1      -0.013051       -0.093843 -0.008736 -0.526994  ...           -0.614839
# 2      -0.013051       -0.093843 -0.008736 -0.526994  ...           -0.347338
# 3      -0.013051       -0.093843 -0.008736 -0.526994  ...            2.102973
# 4      -0.013051       -0.093843 -0.008736 -0.526994  ...            2.102973
# ...          ...             ...       ...       ...  ...                 ...
# 275968 -0.013051       -0.093843 -0.008736  0.006270  ...           -0.625539
# 275969 -0.013051       -0.093843 -0.008736  1.472747  ...           -0.625539
# 275970 -0.013051       -0.093843 -0.008736 -0.127046  ...           -0.625539
# 275971 -0.013051       -0.093843 -0.008736 -0.393678  ...           -0.507838
# 275972 -0.013051       11.175976 -0.008736 -0.260362  ...           -0.475738
#
#         dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    -0.329593               -0.765769
# 1                    -0.730618                0.868059
# 2                    -0.494721               -0.708442
# 3                     1.628353               -0.851760
# 4                     1.628353               -0.851760
# ...                        ...                     ...
# 275968               -0.730618                0.552759
# 275969               -0.730618                2.014605
# 275970               -0.730618                2.014605
# 275971               -0.093696                0.208795
# 275972               -0.730618               -0.765769
#
#         dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                          0.283646                    -0.259759
# 1                          3.049429                    -0.259759
# 2                         -0.378584                    -0.259759
# 3                         -0.261720                     0.227770
# 4                         -0.378584                    -0.259759
# ...                             ...                          ...
# 275968                    -0.378584                    -0.259759
# 275969                    -0.378584                    -0.259759
# 275970                    -0.378584                    -0.259759
# 275971                    -0.378584                    -0.259759
# 275972                    -0.378584                    -0.259759
#
#         dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  -1.145549                 -1.081826             -0.360096
# 1                  -1.145549                 -1.081826             -0.496432
# 2                   0.891163                  0.932580             -0.496432
# 3                  -1.084447                 -1.061681             -0.496432
# 4                  -1.145549                 -1.081826             -0.496432
# ...                      ...                       ...                   ...
# 275968              0.891163                  0.932580             -0.496432
# 275969              0.891163                  0.932580             -0.496432
# 275970              0.891163                  0.932580              2.230282
# 275971              0.891163                  0.932580             -0.496432
# 275972              0.891163                  0.932580             -0.496432
#
#         dst_host_srv_rerror_rate  label
# 0                      -0.466505      2
# 1                      -0.466505      2
# 2                      -0.466505      0
# 3                      -0.439694      2
# 4                      -0.466505      2
# ...                          ...    ...
# 275968                 -0.466505      1
# 275969                 -0.466505      1
# 275970                 -0.466505      1
# 275971                 -0.466505      1
# 275972                 -0.466505      1
#
# [275973 rows x 42 columns]

# %%
y_data= data['label']
X_data= data.drop(labels=['label'], axis=1)

print('X_train has shape:',X_data.shape,'\ny_train has shape:',y_data.shape)
# Out:
# X_train has shape: (275973, 41)
# y_train has shape: (275973,)

# %%
# one-hot-encoding categorical columns
data = pd.get_dummies(data,columns=['protocol_type','service','flag'],prefix="",prefix_sep="")
print(data.shape)
# Out:
# (275973, 123)

# %%
# one-hot-encoding categorical columns
data_test = pd.get_dummies(data_test,columns=['protocol_type','service','flag'],prefix="",prefix_sep="")
print(data_test.shape)
# Out:
# (22544, 117)

# %%
def drop_missing_columns(df1, df2):
    missing_columns = set(df1.columns) - set(df2.columns)
    print(list(missing_columns))
    return df1.drop(missing_columns, axis=1)

data = drop_missing_columns(data, data_test)
data_test = drop_missing_columns(data_test, data)
data
# Out:
# ['aol', 'red_i', 'http_2784', 'harvest', 'urh_i', 'http_8001']
# []
#         duration  src_bytes  dst_bytes      land  wrong_fragment    urgent  \
# 0      -0.085055  -0.005162  -0.003374 -0.013051       -0.093843 -0.008736
# 1      -0.085055  -0.005249  -0.003374 -0.013051       -0.093843 -0.008736
# 2      -0.085055  -0.005286  -0.003374 -0.013051       -0.093843 -0.008736
# 3      -0.085055  -0.005228  -0.000373 -0.013051       -0.093843 -0.008736
# 4      -0.085055  -0.005236  -0.003219 -0.013051       -0.093843 -0.008736
# ...          ...        ...        ...       ...             ...       ...
# 275968 -0.085055  -0.005286  -0.003374 -0.013051       -0.093843 -0.008736
# 275969 -0.084489  -0.005286  -0.003374 -0.013051       -0.093843 -0.008736
# 275970 -0.078828  -0.005286  -0.003374 -0.013051       -0.093843 -0.008736
# 275971 -0.085055  -0.005286  -0.003374 -0.013051       -0.093843 -0.008736
# 275972 -0.085055  -0.005286  -0.003367 -0.013051       11.175976 -0.008736
#
#              hot  num_failed_logins  logged_in  num_compromised  ...    REJ  \
# 0      -0.526994          -0.026678  -0.522053        -0.338593  ...  False
# 1      -0.526994          -0.026678  -0.522053        -0.338593  ...  False
# 2      -0.526994          -0.026678  -0.522053        -0.338593  ...  False
# 3      -0.526994          -0.026678   1.915515        -0.338593  ...  False
# 4      -0.526994          -0.026678   1.915515        -0.338593  ...  False
# ...          ...                ...        ...              ...  ...    ...
# 275968  0.006270          -0.026678  -0.522053         0.319157  ...  False
# 275969  1.472747          -0.026678  -0.522053         0.489137  ...  False
# 275970 -0.127046          -0.026678  -0.522053        -0.242517  ...  False
# 275971 -0.393678          -0.026678  -0.522053         0.178738  ...  False
# 275972 -0.260362          -0.026678  -0.522053        -0.042975  ...   True
#
#          RSTO  RSTOS0   RSTR     S0     S1     S2     S3     SF     SH
# 0       False   False  False  False  False  False  False   True  False
# 1       False   False  False  False  False  False  False   True  False
# 2       False   False  False   True  False  False  False  False  False
# 3       False   False  False  False  False  False  False   True  False
# 4       False   False  False  False  False  False  False   True  False
# ...       ...     ...    ...    ...    ...    ...    ...    ...    ...
# 275968  False   False   True  False  False  False  False  False  False
# 275969   True   False  False  False  False  False  False  False  False
# 275970   True   False  False  False  False  False  False  False  False
# 275971  False   False  False   True  False  False  False  False  False
# 275972  False   False  False  False  False  False  False  False  False
#
# [275973 rows x 117 columns]

# %%
data_test
# Out:
#        duration  src_bytes  dst_bytes      land  wrong_fragment    urgent  \
# 0     -0.155534  -0.021988  -0.096896 -0.017624       -0.059104 -0.019459
# 1     -0.155534  -0.021988  -0.096896 -0.017624       -0.059104 -0.019459
# 2     -0.154113   0.005473  -0.096896 -0.017624       -0.059104 -0.019459
# 3     -0.155534  -0.021946  -0.096896 -0.017624       -0.059104 -0.019459
# 4     -0.154823  -0.021988  -0.096189 -0.017624       -0.059104 -0.019459
# ...         ...        ...        ...       ...             ...       ...
# 22539 -0.155534  -0.020309  -0.081202 -0.017624       -0.059104 -0.019459
# 22540 -0.155534  -0.021318  -0.052690 -0.017624       -0.059104 -0.019459
# 22541 -0.155534   0.093373   0.294926 -0.017624       -0.059104 -0.019459
# 22542 -0.155534  -0.021899  -0.094917 -0.017624       -0.059104 -0.019459
# 22543 -0.155534  -0.021988  -0.096896 -0.017624       -0.059104 -0.019459
#
#             hot  num_failed_logins  logged_in  num_compromised  ...    REJ  \
# 0     -0.113521          -0.143999  -0.890373        -0.016494  ...   True
# 1     -0.113521          -0.143999  -0.890373        -0.016494  ...   True
# 2     -0.113521          -0.143999  -0.890373        -0.016494  ...  False
# 3     -0.113521          -0.143999  -0.890373        -0.016494  ...  False
# 4     -0.113521          -0.143999  -0.890373        -0.016494  ...  False
# ...         ...                ...        ...              ...  ...    ...
# 22539 -0.113521          -0.143999   1.123125        -0.016494  ...  False
# 22540 -0.113521          -0.143999   1.123125        -0.016494  ...  False
# 22541  2.040705          -0.143999   1.123125         0.121069  ...  False
# 22542 -0.113521          -0.143999  -0.890373        -0.016494  ...  False
# 22543 -0.113521          -0.143999  -0.890373        -0.016494  ...   True
#
#         RSTO  RSTOS0   RSTR     S0     S1     S2     S3     SF     SH
# 0      False   False  False  False  False  False  False  False  False
# 1      False   False  False  False  False  False  False  False  False
# 2      False   False  False  False  False  False  False   True  False
# 3      False   False  False  False  False  False  False   True  False
# 4       True   False  False  False  False  False  False  False  False
# ...      ...     ...    ...    ...    ...    ...    ...    ...    ...
# 22539  False   False  False  False  False  False  False   True  False
# 22540  False   False  False  False  False  False  False   True  False
# 22541  False   False  False  False  False  False  False   True  False
# 22542  False   False  False  False  False  False  False   True  False
# 22543  False   False  False  False  False  False  False  False  False
#
# [22544 rows x 117 columns]

# %%
y_data= data['label']
X_data= data.drop(labels=['label'], axis=1)

print('X_train has shape:',X_data.shape,'\ny_train has shape:',y_data.shape)
# Out:
# X_train has shape: (275973, 116)
# y_train has shape: (275973,)

# %%
y_data_test= data_test['label']
X_data_test= data_test.drop(labels=['label'], axis=1)

print('X_test has shape:',X_data_test.shape,'\n y_test has shape:',y_data_test.shape)
# Out:
# X_test has shape: (22544, 116)
#  y_test has shape: (22544,)

# %%
from sklearn.preprocessing import LabelBinarizer
y_data = LabelBinarizer().fit_transform(y_data)

X_data=np.array(X_data)
y_data=np.array(y_data)

# %%
y_data_test = LabelBinarizer().fit_transform(y_data_test)

X_data_test=np.array(X_data_test)
y_data_test=np.array(y_data_test)

# %%
X_train = X_data
X_test = X_data_test
y_train = y_data
y_test  = y_data_test
print(X_train.shape,'\n',X_test.shape)
#print(X_train)
# Out:
# (275973, 116)
#  (22544, 116)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, ( X_train.shape[0], 1 , X_train.shape[1] ))
X_test = np.reshape(X_test, ( X_test.shape[0], 1,  X_test.shape[1] ))

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (275973, 1, 116)
# (22544, 1, 116)

# %%
pip install keras-self-attention
# Out:
# Collecting keras-self-attention
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras-self-attention) (2.0.2)
# Building wheels for collected packages: keras-self-attention
#   Building wheel for keras-self-attention (setup.py) ... done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18895 sha256=c90c54150da567a8876277a39dbc6ed2e6f0ce5696bdb59aa80890be448874e3
#   Stored in directory: /root/.cache/pip/wheels/46/f9/96/709295c836133071c12a300729fed4027757f889c01695feea
# Successfully built keras-self-attention
# Installing collected packages: keras-self-attention
# Successfully installed keras-self-attention-0.51.0

# %%
pip install attention
# Out:
# Collecting attention
#   Downloading attention-5.0.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.11/dist-packages (from attention) (2.0.2)
# Requirement already satisfied: tensorflow>=2.1 in /usr/local/lib/python3.11/dist-packages (from attention) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (3.0.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (4.13.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow>=2.1->attention) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.1->attention) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.1->attention) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.1->attention) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.1->attention) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.1->attention) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.1->attention) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.1->attention) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.1->attention) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.1->attention) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.1->attention) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow>=2.1->attention) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.1->attention) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.1->attention) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow>=2.1->attention) (0.1.2)
# Downloading attention-5.0.0-py3-none-any.whl (9.0 kB)
# Installing collected packages: attention
# Successfully installed attention-5.0.0

# %%
# LSTM MODEL + ATTENTION

import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout,Bidirectional,Masking,LSTM
from keras_self_attention import SeqSelfAttention
from attention import Attention

model = Sequential() # initializing model
model.add(LSTM(64,return_sequences=True,input_shape = (1, X_train.shape[2])))
model.add(Dropout(0.5))
model.add(LSTM(64,return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64,return_sequences=True))
#model.add(Attention(units=64))
model.add(SeqSelfAttention(attention_activation='sigmoid'))
model.add(Flatten())
model.add(Dense(units=50))
# output layer with softmax activation
model.add(Dense(units=3,activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
import tensorflow as tf
#from tensorflow.keras.optimizers import Adam

#optimizer = Adam(learning_rate=0.001)

# defining loss function, optimizer, metrics and then compiling model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy',tf.keras.metrics.Precision(),tf.keras.metrics.Recall()])

# %%
# summary of model layers
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 1, 64)               │          46,336 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1, 64)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 1, 64)               │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 1, 64)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 1, 64)               │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ seq_self_attention                   │ (None, 1, 64)               │           4,161 │
# │ (SeqSelfAttention)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 50)                  │           3,250 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │             153 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 119,948 (468.55 KB)
#  Trainable params: 119,948 (468.55 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Visualize the model

from keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True, expand_nested=True)

# %%
X_train = X_train.astype(float)
print(X_train.shape)
y_train = y_train.astype(float)
print(y_train.shape)
# Out:
# (275973, 1, 116)
# (275973, 3)

# %%
# training the model on training dataset
history = model.fit(X_train, y_train, epochs=50, batch_size=5000,validation_split=0.2)
# Out:
# Epoch 1/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 34s 274ms/step - accuracy: 0.4845 - loss: 1.0273 - precision: 0.5261 - recall: 0.0615 - val_accuracy: 0.9548 - val_loss: 0.2917 - val_precision: 0.9692 - val_recall: 0.9164
# Epoch 2/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 15s 168ms/step - accuracy: 0.8997 - loss: 0.3036 - precision: 0.9272 - recall: 0.8619 - val_accuracy: 0.9709 - val_loss: 0.0692 - val_precision: 0.9737 - val_recall: 0.9675
# Epoch 3/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - accuracy: 0.9647 - loss: 0.1165 - precision: 0.9693 - recall: 0.9596 - val_accuracy: 0.9864 - val_loss: 0.0342 - val_precision: 0.9874 - val_recall: 0.9854
# Epoch 4/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 136ms/step - accuracy: 0.9763 - loss: 0.0819 - precision: 0.9785 - recall: 0.9739 - val_accuracy: 0.9911 - val_loss: 0.0234 - val_precision: 0.9915 - val_recall: 0.9905
# Epoch 5/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 140ms/step - accuracy: 0.9810 - loss: 0.0661 - precision: 0.9822 - recall: 0.9798 - val_accuracy: 0.9938 - val_loss: 0.0161 - val_precision: 0.9942 - val_recall: 0.9935
# Epoch 6/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - accuracy: 0.9825 - loss: 0.0606 - precision: 0.9836 - recall: 0.9815 - val_accuracy: 0.9962 - val_loss: 0.0105 - val_precision: 0.9964 - val_recall: 0.9959
# Epoch 7/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - accuracy: 0.9841 - loss: 0.0551 - precision: 0.9849 - recall: 0.9831 - val_accuracy: 0.9961 - val_loss: 0.0114 - val_precision: 0.9962 - val_recall: 0.9958
# Epoch 8/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 171ms/step - accuracy: 0.9849 - loss: 0.0503 - precision: 0.9857 - recall: 0.9839 - val_accuracy: 0.9971 - val_loss: 0.0084 - val_precision: 0.9972 - val_recall: 0.9969
# Epoch 9/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 161ms/step - accuracy: 0.9862 - loss: 0.0438 - precision: 0.9871 - recall: 0.9853 - val_accuracy: 0.9975 - val_loss: 0.0069 - val_precision: 0.9977 - val_recall: 0.9974
# Epoch 10/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 150ms/step - accuracy: 0.9869 - loss: 0.0402 - precision: 0.9877 - recall: 0.9861 - val_accuracy: 0.9980 - val_loss: 0.0054 - val_precision: 0.9981 - val_recall: 0.9980
# Epoch 11/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 141ms/step - accuracy: 0.9877 - loss: 0.0367 - precision: 0.9884 - recall: 0.9870 - val_accuracy: 0.9982 - val_loss: 0.0052 - val_precision: 0.9982 - val_recall: 0.9980
# Epoch 12/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 12s 172ms/step - accuracy: 0.9883 - loss: 0.0341 - precision: 0.9890 - recall: 0.9877 - val_accuracy: 0.9983 - val_loss: 0.0048 - val_precision: 0.9983 - val_recall: 0.9982
# Epoch 13/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 161ms/step - accuracy: 0.9893 - loss: 0.0309 - precision: 0.9899 - recall: 0.9888 - val_accuracy: 0.9989 - val_loss: 0.0031 - val_precision: 0.9989 - val_recall: 0.9989
# Epoch 14/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 134ms/step - accuracy: 0.9907 - loss: 0.0287 - precision: 0.9911 - recall: 0.9902 - val_accuracy: 0.9990 - val_loss: 0.0025 - val_precision: 0.9990 - val_recall: 0.9990
# Epoch 15/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 193ms/step - accuracy: 0.9914 - loss: 0.0265 - precision: 0.9917 - recall: 0.9910 - val_accuracy: 0.9991 - val_loss: 0.0025 - val_precision: 0.9991 - val_recall: 0.9991
# Epoch 16/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 149ms/step - accuracy: 0.9925 - loss: 0.0238 - precision: 0.9928 - recall: 0.9921 - val_accuracy: 0.9990 - val_loss: 0.0027 - val_precision: 0.9990 - val_recall: 0.9990
# Epoch 17/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.9928 - loss: 0.0222 - precision: 0.9932 - recall: 0.9925 - val_accuracy: 0.9991 - val_loss: 0.0025 - val_precision: 0.9991 - val_recall: 0.9991
# Epoch 18/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.9934 - loss: 0.0210 - precision: 0.9937 - recall: 0.9932 - val_accuracy: 0.9993 - val_loss: 0.0020 - val_precision: 0.9994 - val_recall: 0.9993
# Epoch 19/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 12s 171ms/step - accuracy: 0.9936 - loss: 0.0205 - precision: 0.9940 - recall: 0.9933 - val_accuracy: 0.9993 - val_loss: 0.0022 - val_precision: 0.9993 - val_recall: 0.9993
# Epoch 20/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 135ms/step - accuracy: 0.9938 - loss: 0.0202 - precision: 0.9940 - recall: 0.9935 - val_accuracy: 0.9995 - val_loss: 0.0013 - val_precision: 0.9995 - val_recall: 0.9995
# Epoch 21/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 132ms/step - accuracy: 0.9941 - loss: 0.0190 - precision: 0.9943 - recall: 0.9939 - val_accuracy: 0.9995 - val_loss: 0.0014 - val_precision: 0.9995 - val_recall: 0.9995
# Epoch 22/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 169ms/step - accuracy: 0.9942 - loss: 0.0187 - precision: 0.9944 - recall: 0.9941 - val_accuracy: 0.9996 - val_loss: 0.0012 - val_precision: 0.9996 - val_recall: 0.9996
# Epoch 23/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 133ms/step - accuracy: 0.9948 - loss: 0.0170 - precision: 0.9950 - recall: 0.9946 - val_accuracy: 0.9995 - val_loss: 0.0014 - val_precision: 0.9995 - val_recall: 0.9995
# Epoch 24/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 155ms/step - accuracy: 0.9946 - loss: 0.0174 - precision: 0.9948 - recall: 0.9943 - val_accuracy: 0.9996 - val_loss: 0.0013 - val_precision: 0.9996 - val_recall: 0.9996
# Epoch 25/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 172ms/step - accuracy: 0.9942 - loss: 0.0177 - precision: 0.9944 - recall: 0.9941 - val_accuracy: 0.9996 - val_loss: 0.0014 - val_precision: 0.9996 - val_recall: 0.9996
# Epoch 26/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.9948 - loss: 0.0166 - precision: 0.9950 - recall: 0.9947 - val_accuracy: 0.9996 - val_loss: 0.0014 - val_precision: 0.9996 - val_recall: 0.9996
# Epoch 27/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.9949 - loss: 0.0168 - precision: 0.9950 - recall: 0.9947 - val_accuracy: 0.9997 - val_loss: 9.4031e-04 - val_precision: 0.9997 - val_recall: 0.9997
# Epoch 28/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 171ms/step - accuracy: 0.9952 - loss: 0.0158 - precision: 0.9954 - recall: 0.9951 - val_accuracy: 0.9995 - val_loss: 0.0015 - val_precision: 0.9995 - val_recall: 0.9995
# Epoch 29/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 134ms/step - accuracy: 0.9952 - loss: 0.0161 - precision: 0.9954 - recall: 0.9950 - val_accuracy: 0.9997 - val_loss: 0.0010 - val_precision: 0.9997 - val_recall: 0.9997
# Epoch 30/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 170ms/step - accuracy: 0.9952 - loss: 0.0158 - precision: 0.9954 - recall: 0.9951 - val_accuracy: 0.9994 - val_loss: 0.0015 - val_precision: 0.9995 - val_recall: 0.9994
# Epoch 31/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 137ms/step - accuracy: 0.9951 - loss: 0.0153 - precision: 0.9953 - recall: 0.9950 - val_accuracy: 0.9996 - val_loss: 0.0011 - val_precision: 0.9996 - val_recall: 0.9996
# Epoch 32/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 155ms/step - accuracy: 0.9954 - loss: 0.0147 - precision: 0.9956 - recall: 0.9954 - val_accuracy: 0.9997 - val_loss: 9.6176e-04 - val_precision: 0.9997 - val_recall: 0.9997
# Epoch 33/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 134ms/step - accuracy: 0.9956 - loss: 0.0145 - precision: 0.9957 - recall: 0.9954 - val_accuracy: 0.9997 - val_loss: 0.0011 - val_precision: 0.9997 - val_recall: 0.9997
# Epoch 34/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.9954 - loss: 0.0142 - precision: 0.9955 - recall: 0.9953 - val_accuracy: 0.9996 - val_loss: 0.0014 - val_precision: 0.9996 - val_recall: 0.9996
# Epoch 35/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 170ms/step - accuracy: 0.9955 - loss: 0.0142 - precision: 0.9956 - recall: 0.9954 - val_accuracy: 0.9997 - val_loss: 7.9111e-04 - val_precision: 0.9997 - val_recall: 0.9997
# Epoch 36/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 133ms/step - accuracy: 0.9959 - loss: 0.0139 - precision: 0.9960 - recall: 0.9958 - val_accuracy: 0.9997 - val_loss: 9.1782e-04 - val_precision: 0.9997 - val_recall: 0.9997
# Epoch 37/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 133ms/step - accuracy: 0.9956 - loss: 0.0141 - precision: 0.9957 - recall: 0.9955 - val_accuracy: 0.9996 - val_loss: 0.0011 - val_precision: 0.9996 - val_recall: 0.9996
# Epoch 38/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 139ms/step - accuracy: 0.9959 - loss: 0.0139 - precision: 0.9959 - recall: 0.9958 - val_accuracy: 0.9997 - val_loss: 8.5381e-04 - val_precision: 0.9997 - val_recall: 0.9997
# Epoch 39/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 212ms/step - accuracy: 0.9957 - loss: 0.0137 - precision: 0.9958 - recall: 0.9955 - val_accuracy: 0.9997 - val_loss: 9.0964e-04 - val_precision: 0.9997 - val_recall: 0.9997
# Epoch 40/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 136ms/step - accuracy: 0.9961 - loss: 0.0131 - precision: 0.9961 - recall: 0.9960 - val_accuracy: 0.9997 - val_loss: 7.7233e-04 - val_precision: 0.9997 - val_recall: 0.9997
# Epoch 41/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 15s 235ms/step - accuracy: 0.9957 - loss: 0.0134 - precision: 0.9957 - recall: 0.9956 - val_accuracy: 0.9997 - val_loss: 8.5145e-04 - val_precision: 0.9997 - val_recall: 0.9997
# Epoch 42/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 19s 205ms/step - accuracy: 0.9955 - loss: 0.0138 - precision: 0.9955 - recall: 0.9954 - val_accuracy: 0.9995 - val_loss: 0.0012 - val_precision: 0.9996 - val_recall: 0.9995
# Epoch 43/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - accuracy: 0.9960 - loss: 0.0134 - precision: 0.9960 - recall: 0.9958 - val_accuracy: 0.9996 - val_loss: 0.0012 - val_precision: 0.9996 - val_recall: 0.9996
# Epoch 44/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 178ms/step - accuracy: 0.9958 - loss: 0.0135 - precision: 0.9959 - recall: 0.9957 - val_accuracy: 0.9997 - val_loss: 7.5048e-04 - val_precision: 0.9997 - val_recall: 0.9997
# Epoch 45/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 135ms/step - accuracy: 0.9958 - loss: 0.0131 - precision: 0.9959 - recall: 0.9957 - val_accuracy: 0.9997 - val_loss: 7.6391e-04 - val_precision: 0.9997 - val_recall: 0.9997
# Epoch 46/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 161ms/step - accuracy: 0.9958 - loss: 0.0131 - precision: 0.9959 - recall: 0.9957 - val_accuracy: 0.9998 - val_loss: 6.4000e-04 - val_precision: 0.9998 - val_recall: 0.9998
# Epoch 47/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 184ms/step - accuracy: 0.9960 - loss: 0.0129 - precision: 0.9961 - recall: 0.9959 - val_accuracy: 0.9997 - val_loss: 7.7234e-04 - val_precision: 0.9997 - val_recall: 0.9997
# Epoch 48/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 136ms/step - accuracy: 0.9962 - loss: 0.0126 - precision: 0.9963 - recall: 0.9961 - val_accuracy: 0.9996 - val_loss: 0.0010 - val_precision: 0.9996 - val_recall: 0.9996
# Epoch 49/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 132ms/step - accuracy: 0.9960 - loss: 0.0129 - precision: 0.9961 - recall: 0.9959 - val_accuracy: 0.9998 - val_loss: 6.8752e-04 - val_precision: 0.9998 - val_recall: 0.9998
# Epoch 50/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 156ms/step - accuracy: 0.9962 - loss: 0.0116 - precision: 0.9963 - recall: 0.9961 - val_accuracy: 0.9997 - val_loss: 8.4132e-04 - val_precision: 0.9997 - val_recall: 0.9997

# %%
X_test = X_test.astype(float)
y_test = y_test.astype(float)

# %%
# predicting target attribute on testing dataset
test_results = model.evaluate(X_test, y_test,verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')
# Out:
# 705/705 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.1247 - loss: 18.4477 - precision: 0.1246 - recall: 0.1246
# Test results - Loss: 18.382713317871094 - Accuracy: 12.850426137447357%

# %%
results = model.evaluate(X_test, y_test,batch_size = 128)
# Out:
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1249 - loss: 18.4450 - precision: 0.1248 - recall: 0.1248

# %%
print(model.metrics_names)
print(results)
# Out:
# ['loss', 'compile_metrics']
# [18.38271141052246, 0.12850426137447357, 0.12846559286117554, 0.1284599006175995]

# %%
# # Plot of accuracy vs epoch for train and test dataset
# plt.plot(history.history['accuracy'])
# plt.plot(history.history['val_accuracy'])
# plt.title("Plot of accuracy vs epoch for train and test dataset")
# plt.ylabel('accuracy')
# plt.xlabel('epoch')
# plt.show()
pd.DataFrame(history.history)
pd.DataFrame(history.history)[['accuracy','val_accuracy']].plot()
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
# Out:
# Text(0.5, 0, 'Epochs')

# %%
# # Plot of loss vs epoch for train and test dataset
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title("Plot of loss vs epoch for train and test dataset")
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper right')
# plt.show()
pd.DataFrame(history.history)
pd.DataFrame(history.history)[['loss','val_loss']].plot()
plt.ylabel('Model Loss')
plt.xlabel('Epochs')
# Out:
# Text(0.5, 0, 'Epochs')

# %%
from sklearn.metrics import classification_report

y_predict = model.predict(X_test)
y_pred = y_predict.argmax(axis=-1)
y_test = y_test.argmax(axis = -1 )
report = classification_report(y_test, y_pred)
print(report)
print(y_pred)
df1 = pd.DataFrame(y_pred)
# saving the dataframe
df1.to_csv('/content/drive/MyDrive/DLC-IDS/Outputs/CR.csv', index = False)
# Out:
# 705/705 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.68      0.00      0.00      9948
#            1       0.13      1.00      0.23      2885
#            2       0.02      0.00      0.00      9711
#
#     accuracy                           0.13     22544
#    macro avg       0.28      0.33      0.08     22544
# weighted avg       0.33      0.13      0.03     22544
#
# [1 1 1 ... 1 1 1]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)
# create a ConfusionMatrixDisplay object
cm_display = ConfusionMatrixDisplay(cm)
# plot the confusion matrix
print("Confusion Matrix:\n", cm)
cm_display.plot()
plt.show()
# Out:
# Confusion Matrix:
#  [[  13 9489  446]
#  [   1 2873   11]
#  [   5 9695   11]]

# %%
import numpy as np


def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):

    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

# %%
from sklearn.metrics import confusion_matrix
plot_confusion_matrix(cm=confusion_matrix(y_test, y_pred),
                      normalize=False,
                      target_names=[],
                      title="Confusion Matrix")

# %%
from sklearn.metrics import confusion_matrix
plot_confusion_matrix(cm=confusion_matrix(y_test, y_pred),
                      normalize=True,
                      target_names=[],
                      title="Confusion Matrix")

# %%
model.save("NSL-KDD LSTM.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
