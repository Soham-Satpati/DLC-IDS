# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# importing required libraries
import numpy as np
import pandas as pd
import pickle # saving and loading trained model
from os import path

# importing required libraries for normalizing data
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# importing library for plotting
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

#import tensorflow as tf
from tensorflow.keras.utils import to_categorical

from keras.layers import Dense, LSTM, MaxPool1D, Flatten, Dropout, Bidirectional # importing dense layer
from keras.models import Sequential #importing Sequential layer
from keras.layers import Input
from keras.models import Model
# representation of model layers
from tensorflow.keras.utils import plot_model

# %%
# Generated Train + Test merged Datasets
data = pd.read_csv('/content/drive/MyDrive/DLC-IDS/Datasets/train_merged_DOS_sdv.csv')
data_test = pd.read_csv('/content/drive/MyDrive/DLC-IDS/Datasets/test_merged_DOS.csv')

# %%
# number of attack labels for train data
data['label'].value_counts()
# Out:
# label
# Dos       75927
# normal    67343
# Other     12703
# Name: count, dtype: int64

# %%
# number of attack labels for test data
data_test['label'].value_counts()
# Out:
# label
# normal    9711
# Dos       7460
# Other     5373
# Name: count, dtype: int64

# %%
label = pd.DataFrame(data.label)
label_test = pd.DataFrame(data_test.label)

# %%
# using standard scaler for normalizing
std_scaler = StandardScaler()
def standardization(df,col):
    for i in col:
        arr = df[i]
        arr = np.array(arr)
        df[i] = std_scaler.fit_transform(arr.reshape(len(arr),1))
    return df

numeric_col = data.select_dtypes(include='number').columns
data = standardization(data,numeric_col)
numeric_col = data_test.select_dtypes(include='number').columns
data_test = standardization(data_test,numeric_col)

# %%
data['label'].replace(('normal', 'Dos', 'Other'), (2, 1, 0), inplace=True)
print(data.shape)
data
# Out:
# <ipython-input-8-ce66f74de1cb>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['label'].replace(('normal', 'Dos', 'Other'), (2, 1, 0), inplace=True)
# <ipython-input-8-ce66f74de1cb>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['label'].replace(('normal', 'Dos', 'Other'), (2, 1, 0), inplace=True)
# (155973, 42)
#         duration protocol_type   service flag  src_bytes  dst_bytes      land  \
# 0      -0.102969           tcp  ftp_data   SF  -0.007165  -0.004897 -0.014547
# 1      -0.102969           udp     other   SF  -0.007231  -0.004897 -0.014547
# 2      -0.102969           tcp   private   S0  -0.007259  -0.004897 -0.014547
# 3      -0.102969           tcp      http   SF  -0.007215  -0.002641 -0.014547
# 4      -0.102969           tcp      http   SF  -0.007221  -0.004780 -0.014547
# ...          ...           ...       ...  ...        ...        ...       ...
# 155968 -0.101688           tcp      http   SF   0.004170   0.035006 -0.014547
# 155969 -0.076938           tcp   private   S0  -0.007228  -0.003119 -0.014547
# 155970 -0.102969           tcp     pop_3   S0  -0.007258  -0.004896 -0.014547
# 155971 -0.064563           tcp    klogin   SF  -0.005393  -0.000709 -0.014547
# 155972 -0.098701           udp   private   S0  -0.007102   0.000496 -0.014547
#
#         wrong_fragment    urgent       hot  ...  dst_host_srv_count  \
# 0            -0.089035 -0.007596 -0.290570  ...           -0.736393
# 1            -0.089035 -0.007596 -0.290570  ...           -0.962028
# 2            -0.089035 -0.007596 -0.290570  ...           -0.726992
# 3            -0.089035 -0.007596 -0.290570  ...            1.425938
# 4            -0.089035 -0.007596 -0.290570  ...            1.425938
# ...                ...       ...       ...  ...                 ...
# 155968       -0.089035 -0.007596  1.439084  ...            0.598611
# 155969       -0.089035 -0.007596  0.358050  ...           -0.924422
# 155970       -0.089035 -0.007596  0.574257  ...           -0.933823
# 155971       -0.089035 -0.007596  1.006671  ...            0.354174
# 155972       -0.089035 -0.007596  0.574257  ...           -0.604773
#
#         dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    -0.702341               -0.375891
# 1                    -1.079134                2.253022
# 2                    -0.857491               -0.283649
# 3                     1.137298               -0.514255
# 4                     1.137298               -0.514255
# ...                        ...                     ...
# 155968                1.137298               -0.514255
# 155969               -1.079134                2.299143
# 155970               -1.079134               -0.099164
# 155971                1.137298               -0.006921
# 155972               -0.768834               -0.422013
#
#         dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                          0.081241                    -0.312135
# 1                          2.398065                    -0.312135
# 2                         -0.473492                    -0.312135
# 3                         -0.375598                     0.061648
# 4                         -0.473492                    -0.312135
# ...                             ...                          ...
# 155968                     0.407554                     1.089550
# 155969                    -0.408229                    -0.312135
# 155970                    -0.473492                    -0.312135
# 155971                    -0.473492                    -0.312135
# 155972                     0.831761                    -0.312135
#
#         dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  -0.675039                 -0.654739             -0.241978
# 1                  -0.675039                 -0.654739             -0.400908
# 2                   1.522385                  1.544533             -0.400908
# 3                  -0.609117                 -0.632746             -0.400908
# 4                  -0.675039                 -0.654739             -0.400908
# ...                      ...                       ...                   ...
# 155968             -0.675039                 -0.654739             -0.400908
# 155969              1.478437                 -0.654739              0.044096
# 155970              1.522385                  1.544533             -0.400908
# 155971             -0.675039                 -0.654739             -0.369122
# 155972             -0.675039                 -0.654739             -0.400908
#
#         dst_host_srv_rerror_rate  label
# 0                      -0.388768      2
# 1                      -0.388768      2
# 2                      -0.388768      1
# 3                      -0.358236      2
# 4                      -0.388768      2
# ...                          ...    ...
# 155968                 -0.388768      1
# 155969                 -0.388768      1
# 155970                 -0.388768      1
# 155971                 -0.388768      1
# 155972                 -0.388768      1
#
# [155973 rows x 42 columns]

# %%
data_test['label'].replace(('normal', 'Dos', 'Other'), (2, 1, 0), inplace=True)
print(data_test.shape)
data_test
# Out:
# (22544, 42)
# <ipython-input-9-90a2b101b524>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_test['label'].replace(('normal', 'Dos', 'Other'), (2, 1, 0), inplace=True)
# <ipython-input-9-90a2b101b524>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_test['label'].replace(('normal', 'Dos', 'Other'), (2, 1, 0), inplace=True)
#        duration protocol_type   service  flag  src_bytes  dst_bytes      land  \
# 0     -0.155534           tcp   private   REJ  -0.021988  -0.096896 -0.017624
# 1     -0.155534           tcp   private   REJ  -0.021988  -0.096896 -0.017624
# 2     -0.154113           tcp  ftp_data    SF   0.005473  -0.096896 -0.017624
# 3     -0.155534          icmp     eco_i    SF  -0.021946  -0.096896 -0.017624
# 4     -0.154823           tcp    telnet  RSTO  -0.021988  -0.096189 -0.017624
# ...         ...           ...       ...   ...        ...        ...       ...
# 22539 -0.155534           tcp      smtp    SF  -0.020309  -0.081202 -0.017624
# 22540 -0.155534           tcp      http    SF  -0.021318  -0.052690 -0.017624
# 22541 -0.155534           tcp      http    SF   0.093373   0.294926 -0.017624
# 22542 -0.155534           udp  domain_u    SF  -0.021899  -0.094917 -0.017624
# 22543 -0.155534           tcp    sunrpc   REJ  -0.021988  -0.096896 -0.017624
#
#        wrong_fragment    urgent       hot  ...  dst_host_srv_count  \
# 0           -0.059104 -0.019459 -0.113521  ...           -1.169697
# 1           -0.059104 -0.019459 -0.113521  ...           -1.250212
# 2           -0.059104 -0.019459 -0.113521  ...           -0.489800
# 3           -0.059104 -0.019459 -0.113521  ...           -0.749234
# 4           -0.059104 -0.019459 -0.113521  ...           -0.489800
# ...               ...       ...       ...  ...                 ...
# 22539       -0.059104 -0.019459 -0.113521  ...            0.002232
# 22540       -0.059104 -0.019459 -0.113521  ...            1.022079
# 22541       -0.059104 -0.019459  2.040705  ...            1.022079
# 22542       -0.059104 -0.019459 -0.113521  ...            0.995240
# 22543       -0.059104 -0.019459 -0.113521  ...           -1.071291
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                   -1.305370               -0.138370
# 1                   -1.397181               -0.138370
# 2                    0.002934               -0.228985
# 3                    0.898090               -0.410217
# 4                   -0.685647                0.360018
# ...                       ...                     ...
# 22539                0.255414               -0.138370
# 22540                0.898090               -0.410217
# 22541                0.898090               -0.410217
# 22542                0.875137               -0.364909
# 22543               -1.213559               -0.274293
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                        -0.431856                    -0.229980
# 1                        -0.431856                    -0.229980
# 2                         1.559906                     0.004234
# 3                         2.833328                     3.049016
# 4                        -0.333901                     0.004234
# ...                            ...                          ...
# 22539                    -0.399204                    -0.112873
# 22540                    -0.399204                    -0.112873
# 22541                    -0.431856                    -0.229980
# 22542                    -0.431856                    -0.229980
# 22543                    -0.431856                    -0.229980
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                 -0.358118                  -0.35275              1.979791
# 1                 -0.358118                  -0.35275              1.979791
# 2                 -0.358118                  -0.35275             -0.602719
# 3                 -0.358118                  -0.35275             -0.602719
# 4                 -0.358118                  -0.35275              1.540764
# ...                     ...                       ...                   ...
# 22539             -0.321505                  -0.35275             -0.602719
# 22540             -0.321505                  -0.35275             -0.602719
# 22541             -0.358118                  -0.35275             -0.421943
# 22542             -0.358118                  -0.35275             -0.602719
# 22543             -0.358118                  -0.35275              0.533585
#
#        dst_host_srv_rerror_rate  label
# 0                      1.929116      1
# 1                      1.929116      1
# 2                     -0.565483      2
# 3                     -0.565483      0
# 4                      1.205682      0
# ...                         ...    ...
# 22539                 -0.565483      2
# 22540                 -0.565483      2
# 22541                 -0.390861      1
# 22542                 -0.565483      2
# 22543                  1.929116      0
#
# [22544 rows x 42 columns]

# %%
y_data= data['label']
X_data= data.drop(labels=['label'], axis=1)

print('X_train has shape:',X_data.shape,'\ny_train has shape:',y_data.shape)
# Out:
# X_train has shape: (155973, 41)
# y_train has shape: (155973,)

# %%
# one-hot-encoding categorical columns
data = pd.get_dummies(data,columns=['protocol_type','service','flag'],prefix="",prefix_sep="")
print(data.shape)
# Out:
# (155973, 123)

# %%
# one-hot-encoding categorical columns
data_test = pd.get_dummies(data_test,columns=['protocol_type','service','flag'],prefix="",prefix_sep="")
print(data_test.shape)
# Out:
# (22544, 117)

# %%
def drop_missing_columns(df1, df2):
    missing_columns = set(df1.columns) - set(df2.columns)
    print(list(missing_columns))
    return df1.drop(missing_columns, axis=1)

data = drop_missing_columns(data, data_test)
data_test = drop_missing_columns(data_test, data)
data
# Out:
# ['http_8001', 'red_i', 'http_2784', 'urh_i', 'harvest', 'aol']
# []
#         duration  src_bytes  dst_bytes      land  wrong_fragment    urgent  \
# 0      -0.102969  -0.007165  -0.004897 -0.014547       -0.089035 -0.007596
# 1      -0.102969  -0.007231  -0.004897 -0.014547       -0.089035 -0.007596
# 2      -0.102969  -0.007259  -0.004897 -0.014547       -0.089035 -0.007596
# 3      -0.102969  -0.007215  -0.002641 -0.014547       -0.089035 -0.007596
# 4      -0.102969  -0.007221  -0.004780 -0.014547       -0.089035 -0.007596
# ...          ...        ...        ...       ...             ...       ...
# 155968 -0.101688   0.004170   0.035006 -0.014547       -0.089035 -0.007596
# 155969 -0.076938  -0.007228  -0.003119 -0.014547       -0.089035 -0.007596
# 155970 -0.102969  -0.007258  -0.004896 -0.014547       -0.089035 -0.007596
# 155971 -0.064563  -0.005393  -0.000709 -0.014547       -0.089035 -0.007596
# 155972 -0.098701  -0.007102   0.000496 -0.014547       -0.089035 -0.007596
#
#              hot  num_failed_logins  logged_in  num_compromised  ...    REJ  \
# 0      -0.290570          -0.026555  -0.758628        -0.184683  ...  False
# 1      -0.290570          -0.026555  -0.758628        -0.184683  ...  False
# 2      -0.290570          -0.026555  -0.758628        -0.184683  ...  False
# 3      -0.290570          -0.026555   1.318169        -0.184683  ...  False
# 4      -0.290570          -0.026555   1.318169        -0.184683  ...  False
# ...          ...                ...        ...              ...  ...    ...
# 155968  1.439084          -0.026555   1.318169         0.792229  ...  False
# 155969  0.358050          -0.026555  -0.758628        -0.184683  ...  False
# 155970  0.574257          -0.026555   1.318169        -0.184683  ...  False
# 155971  1.006671          -0.026555  -0.758628         0.200940  ...  False
# 155972  0.574257          -0.026555  -0.758628        -0.184683  ...  False
#
#          RSTO  RSTOS0   RSTR     S0     S1     S2     S3     SF     SH
# 0       False   False  False  False  False  False  False   True  False
# 1       False   False  False  False  False  False  False   True  False
# 2       False   False  False   True  False  False  False  False  False
# 3       False   False  False  False  False  False  False   True  False
# 4       False   False  False  False  False  False  False   True  False
# ...       ...     ...    ...    ...    ...    ...    ...    ...    ...
# 155968  False   False  False  False  False  False  False   True  False
# 155969  False   False  False   True  False  False  False  False  False
# 155970  False   False  False   True  False  False  False  False  False
# 155971  False   False  False  False  False  False  False   True  False
# 155972  False   False  False   True  False  False  False  False  False
#
# [155973 rows x 117 columns]

# %%
data_test
# Out:
#        duration  src_bytes  dst_bytes      land  wrong_fragment    urgent  \
# 0     -0.155534  -0.021988  -0.096896 -0.017624       -0.059104 -0.019459
# 1     -0.155534  -0.021988  -0.096896 -0.017624       -0.059104 -0.019459
# 2     -0.154113   0.005473  -0.096896 -0.017624       -0.059104 -0.019459
# 3     -0.155534  -0.021946  -0.096896 -0.017624       -0.059104 -0.019459
# 4     -0.154823  -0.021988  -0.096189 -0.017624       -0.059104 -0.019459
# ...         ...        ...        ...       ...             ...       ...
# 22539 -0.155534  -0.020309  -0.081202 -0.017624       -0.059104 -0.019459
# 22540 -0.155534  -0.021318  -0.052690 -0.017624       -0.059104 -0.019459
# 22541 -0.155534   0.093373   0.294926 -0.017624       -0.059104 -0.019459
# 22542 -0.155534  -0.021899  -0.094917 -0.017624       -0.059104 -0.019459
# 22543 -0.155534  -0.021988  -0.096896 -0.017624       -0.059104 -0.019459
#
#             hot  num_failed_logins  logged_in  num_compromised  ...    REJ  \
# 0     -0.113521          -0.143999  -0.890373        -0.016494  ...   True
# 1     -0.113521          -0.143999  -0.890373        -0.016494  ...   True
# 2     -0.113521          -0.143999  -0.890373        -0.016494  ...  False
# 3     -0.113521          -0.143999  -0.890373        -0.016494  ...  False
# 4     -0.113521          -0.143999  -0.890373        -0.016494  ...  False
# ...         ...                ...        ...              ...  ...    ...
# 22539 -0.113521          -0.143999   1.123125        -0.016494  ...  False
# 22540 -0.113521          -0.143999   1.123125        -0.016494  ...  False
# 22541  2.040705          -0.143999   1.123125         0.121069  ...  False
# 22542 -0.113521          -0.143999  -0.890373        -0.016494  ...  False
# 22543 -0.113521          -0.143999  -0.890373        -0.016494  ...   True
#
#         RSTO  RSTOS0   RSTR     S0     S1     S2     S3     SF     SH
# 0      False   False  False  False  False  False  False  False  False
# 1      False   False  False  False  False  False  False  False  False
# 2      False   False  False  False  False  False  False   True  False
# 3      False   False  False  False  False  False  False   True  False
# 4       True   False  False  False  False  False  False  False  False
# ...      ...     ...    ...    ...    ...    ...    ...    ...    ...
# 22539  False   False  False  False  False  False  False   True  False
# 22540  False   False  False  False  False  False  False   True  False
# 22541  False   False  False  False  False  False  False   True  False
# 22542  False   False  False  False  False  False  False   True  False
# 22543  False   False  False  False  False  False  False  False  False
#
# [22544 rows x 117 columns]

# %%
y_data= data['label']
X_data= data.drop(labels=['label'], axis=1)

print('X_train has shape:',X_data.shape,'\ny_train has shape:',y_data.shape)
# Out:
# X_train has shape: (155973, 116)
# y_train has shape: (155973,)

# %%
y_data_test= data_test['label']
X_data_test= data_test.drop(labels=['label'], axis=1)

print('X_test has shape:',X_data_test.shape,'\n y_test has shape:',y_data_test.shape)
# Out:
# X_test has shape: (22544, 116)
#  y_test has shape: (22544,)

# %%
from sklearn.preprocessing import LabelBinarizer
y_data = LabelBinarizer().fit_transform(y_data)

X_data=np.array(X_data)
y_data=np.array(y_data)

# %%
y_data_test = LabelBinarizer().fit_transform(y_data_test)

X_data_test=np.array(X_data_test)
y_data_test=np.array(y_data_test)

# %%
X_train = X_data
X_test = X_data_test
y_train = y_data
y_test  = y_data_test
print(X_train.shape,'\n',X_test.shape)
#print(X_train)
# Out:
# (155973, 116)
#  (22544, 116)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, ( X_train.shape[0], 1 , X_train.shape[1] ))
X_test = np.reshape(X_test, ( X_test.shape[0], 1,  X_test.shape[1] ))

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (155973, 1, 116)
# (22544, 1, 116)

# %%
pip install keras-self-attention
# Out:
# Collecting keras-self-attention
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras-self-attention) (2.0.2)
# Building wheels for collected packages: keras-self-attention
#   Building wheel for keras-self-attention (setup.py) ... done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18895 sha256=b63ebaea327a32afc99da2ea174a20f99250a2fc5560fd0f8d8a73fd7a2b7bac
#   Stored in directory: /root/.cache/pip/wheels/46/f9/96/709295c836133071c12a300729fed4027757f889c01695feea
# Successfully built keras-self-attention
# Installing collected packages: keras-self-attention
# Successfully installed keras-self-attention-0.51.0

# %%
pip install attention
# Out:
# Collecting attention
#   Downloading attention-5.0.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.11/dist-packages (from attention) (2.0.2)
# Requirement already satisfied: tensorflow>=2.1 in /usr/local/lib/python3.11/dist-packages (from attention) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow>=2.1->attention) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.1->attention) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.1->attention) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.1->attention) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.1->attention) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.1->attention) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.1->attention) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.1->attention) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.1->attention) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.1->attention) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.1->attention) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow>=2.1->attention) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.1->attention) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.1->attention) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow>=2.1->attention) (0.1.2)
# Downloading attention-5.0.0-py3-none-any.whl (9.0 kB)
# Installing collected packages: attention
# Successfully installed attention-5.0.0

# %%
# LSTM MODEL + ATTENTION

import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout,Bidirectional,Masking,LSTM
from keras_self_attention import SeqSelfAttention
from attention import Attention

model = Sequential() # initializing model
model.add(LSTM(64,return_sequences=True,input_shape = (1, X_train.shape[2])))
model.add(Dropout(0.5))
model.add(LSTM(64,return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64,return_sequences=True))
#model.add(Attention(units=64))
model.add(SeqSelfAttention(attention_activation='sigmoid'))
model.add(Flatten())
model.add(Dense(units=50))
# output layer with softmax activation
model.add(Dense(units=3,activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
import tensorflow as tf
#from tensorflow.keras.optimizers import Adam

#optimizer = Adam(learning_rate=0.001)

# defining loss function, optimizer, metrics and then compiling model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy',tf.keras.metrics.Precision(),tf.keras.metrics.Recall()])

# %%
# summary of model layers
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 1, 64)               │          46,336 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1, 64)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 1, 64)               │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 1, 64)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 1, 64)               │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ seq_self_attention                   │ (None, 1, 64)               │           4,161 │
# │ (SeqSelfAttention)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 50)                  │           3,250 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │             153 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 119,948 (468.55 KB)
#  Trainable params: 119,948 (468.55 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Visualize the model

from keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True, expand_nested=True)

# %%
X_train = X_train.astype(float)
print(X_train.shape)
y_train = y_train.astype(float)
print(y_train.shape)
# Out:
# (155973, 1, 116)
# (155973, 3)

# %%
# training the model on training dataset
history = model.fit(X_train, y_train, epochs=50, batch_size=5000,validation_split=0.2)
# Out:
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 378ms/step - accuracy: 0.4822 - loss: 0.6745 - precision: 0.3024 - recall: 0.0098 - val_accuracy: 0.2295 - val_loss: 0.6738 - val_precision: 0.1187 - val_recall: 0.0193
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8154 - loss: 0.4587 - precision: 0.8917 - recall: 0.5732 - val_accuracy: 0.5972 - val_loss: 0.7574 - val_precision: 0.5989 - val_recall: 0.5237
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.8824 - loss: 0.2244 - precision: 0.9046 - recall: 0.8785 - val_accuracy: 0.6185 - val_loss: 0.5896 - val_precision: 0.6325 - val_recall: 0.5706
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 187ms/step - accuracy: 0.9151 - loss: 0.1397 - precision: 0.9372 - recall: 0.8980 - val_accuracy: 0.5992 - val_loss: 0.5685 - val_precision: 0.6279 - val_recall: 0.5550
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.9626 - loss: 0.1024 - precision: 0.9665 - recall: 0.9580 - val_accuracy: 0.5443 - val_loss: 0.6441 - val_precision: 0.5591 - val_recall: 0.5119
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - accuracy: 0.9720 - loss: 0.0755 - precision: 0.9735 - recall: 0.9706 - val_accuracy: 0.5057 - val_loss: 0.7429 - val_precision: 0.5149 - val_recall: 0.4812
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 201ms/step - accuracy: 0.9758 - loss: 0.0620 - precision: 0.9768 - recall: 0.9748 - val_accuracy: 0.4939 - val_loss: 0.8173 - val_precision: 0.5017 - val_recall: 0.4732
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.9781 - loss: 0.0547 - precision: 0.9788 - recall: 0.9776 - val_accuracy: 0.4950 - val_loss: 0.8512 - val_precision: 0.5016 - val_recall: 0.4756
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9790 - loss: 0.0501 - precision: 0.9794 - recall: 0.9783 - val_accuracy: 0.5011 - val_loss: 0.8737 - val_precision: 0.5073 - val_recall: 0.4833
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.9787 - loss: 0.0482 - precision: 0.9793 - recall: 0.9783 - val_accuracy: 0.5184 - val_loss: 0.8893 - val_precision: 0.5241 - val_recall: 0.5027
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.9802 - loss: 0.0414 - precision: 0.9807 - recall: 0.9796 - val_accuracy: 0.5534 - val_loss: 0.8769 - val_precision: 0.5598 - val_recall: 0.5410
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9824 - loss: 0.0350 - precision: 0.9829 - recall: 0.9820 - val_accuracy: 0.5913 - val_loss: 0.8680 - val_precision: 0.5964 - val_recall: 0.5813
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9836 - loss: 0.0316 - precision: 0.9841 - recall: 0.9832 - val_accuracy: 0.6158 - val_loss: 0.8591 - val_precision: 0.6206 - val_recall: 0.6074
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 0.9866 - loss: 0.0271 - precision: 0.9870 - recall: 0.9862 - val_accuracy: 0.6293 - val_loss: 0.8702 - val_precision: 0.6337 - val_recall: 0.6219
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.9875 - loss: 0.0251 - precision: 0.9879 - recall: 0.9873 - val_accuracy: 0.6415 - val_loss: 0.8743 - val_precision: 0.6459 - val_recall: 0.6356
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.9887 - loss: 0.0237 - precision: 0.9889 - recall: 0.9884 - val_accuracy: 0.6497 - val_loss: 0.8743 - val_precision: 0.6537 - val_recall: 0.6437
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 167ms/step - accuracy: 0.9893 - loss: 0.0222 - precision: 0.9896 - recall: 0.9891 - val_accuracy: 0.6572 - val_loss: 0.8740 - val_precision: 0.6615 - val_recall: 0.6523
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 150ms/step - accuracy: 0.9900 - loss: 0.0212 - precision: 0.9902 - recall: 0.9898 - val_accuracy: 0.6603 - val_loss: 0.8821 - val_precision: 0.6645 - val_recall: 0.6561
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 223ms/step - accuracy: 0.9910 - loss: 0.0193 - precision: 0.9911 - recall: 0.9908 - val_accuracy: 0.6611 - val_loss: 0.8946 - val_precision: 0.6652 - val_recall: 0.6573
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 138ms/step - accuracy: 0.9905 - loss: 0.0194 - precision: 0.9907 - recall: 0.9903 - val_accuracy: 0.6623 - val_loss: 0.9068 - val_precision: 0.6656 - val_recall: 0.6586
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - accuracy: 0.9904 - loss: 0.0191 - precision: 0.9907 - recall: 0.9902 - val_accuracy: 0.6616 - val_loss: 0.9182 - val_precision: 0.6648 - val_recall: 0.6577
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 193ms/step - accuracy: 0.9911 - loss: 0.0186 - precision: 0.9912 - recall: 0.9911 - val_accuracy: 0.6551 - val_loss: 0.9488 - val_precision: 0.6580 - val_recall: 0.6507
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9920 - loss: 0.0175 - precision: 0.9920 - recall: 0.9919 - val_accuracy: 0.6543 - val_loss: 0.9591 - val_precision: 0.6573 - val_recall: 0.6505
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - accuracy: 0.9918 - loss: 0.0170 - precision: 0.9919 - recall: 0.9916 - val_accuracy: 0.6536 - val_loss: 0.9742 - val_precision: 0.6563 - val_recall: 0.6499
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9916 - loss: 0.0176 - precision: 0.9917 - recall: 0.9915 - val_accuracy: 0.6520 - val_loss: 0.9854 - val_precision: 0.6548 - val_recall: 0.6482
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 191ms/step - accuracy: 0.9916 - loss: 0.0170 - precision: 0.9917 - recall: 0.9915 - val_accuracy: 0.6516 - val_loss: 0.9960 - val_precision: 0.6543 - val_recall: 0.6482
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.9922 - loss: 0.0157 - precision: 0.9923 - recall: 0.9921 - val_accuracy: 0.6464 - val_loss: 1.0205 - val_precision: 0.6496 - val_recall: 0.6436
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.9922 - loss: 0.0167 - precision: 0.9923 - recall: 0.9921 - val_accuracy: 0.6466 - val_loss: 1.0248 - val_precision: 0.6489 - val_recall: 0.6434
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 177ms/step - accuracy: 0.9919 - loss: 0.0165 - precision: 0.9920 - recall: 0.9919 - val_accuracy: 0.6442 - val_loss: 1.0457 - val_precision: 0.6463 - val_recall: 0.6411
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.9925 - loss: 0.0161 - precision: 0.9926 - recall: 0.9924 - val_accuracy: 0.6415 - val_loss: 1.0616 - val_precision: 0.6437 - val_recall: 0.6384
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 139ms/step - accuracy: 0.9927 - loss: 0.0148 - precision: 0.9928 - recall: 0.9927 - val_accuracy: 0.6414 - val_loss: 1.0660 - val_precision: 0.6435 - val_recall: 0.6387
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step - accuracy: 0.9930 - loss: 0.0145 - precision: 0.9931 - recall: 0.9929 - val_accuracy: 0.6384 - val_loss: 1.0823 - val_precision: 0.6409 - val_recall: 0.6359
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - accuracy: 0.9930 - loss: 0.0155 - precision: 0.9931 - recall: 0.9929 - val_accuracy: 0.6358 - val_loss: 1.0898 - val_precision: 0.6381 - val_recall: 0.6334
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 134ms/step - accuracy: 0.9930 - loss: 0.0143 - precision: 0.9930 - recall: 0.9929 - val_accuracy: 0.6368 - val_loss: 1.0888 - val_precision: 0.6392 - val_recall: 0.6346
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 204ms/step - accuracy: 0.9928 - loss: 0.0147 - precision: 0.9929 - recall: 0.9927 - val_accuracy: 0.6336 - val_loss: 1.1095 - val_precision: 0.6358 - val_recall: 0.6316
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 157ms/step - accuracy: 0.9929 - loss: 0.0145 - precision: 0.9930 - recall: 0.9929 - val_accuracy: 0.6353 - val_loss: 1.1167 - val_precision: 0.6375 - val_recall: 0.6334
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.9933 - loss: 0.0141 - precision: 0.9933 - recall: 0.9933 - val_accuracy: 0.6329 - val_loss: 1.1361 - val_precision: 0.6351 - val_recall: 0.6311
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9934 - loss: 0.0136 - precision: 0.9934 - recall: 0.9933 - val_accuracy: 0.6324 - val_loss: 1.1397 - val_precision: 0.6342 - val_recall: 0.6303
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 182ms/step - accuracy: 0.9934 - loss: 0.0141 - precision: 0.9935 - recall: 0.9933 - val_accuracy: 0.6307 - val_loss: 1.1473 - val_precision: 0.6323 - val_recall: 0.6284
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.9934 - loss: 0.0142 - precision: 0.9934 - recall: 0.9933 - val_accuracy: 0.6231 - val_loss: 1.1915 - val_precision: 0.6251 - val_recall: 0.6211
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - accuracy: 0.9933 - loss: 0.0140 - precision: 0.9934 - recall: 0.9932 - val_accuracy: 0.6265 - val_loss: 1.1776 - val_precision: 0.6285 - val_recall: 0.6247
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 192ms/step - accuracy: 0.9933 - loss: 0.0135 - precision: 0.9934 - recall: 0.9933 - val_accuracy: 0.6246 - val_loss: 1.2067 - val_precision: 0.6261 - val_recall: 0.6226
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.9939 - loss: 0.0126 - precision: 0.9940 - recall: 0.9939 - val_accuracy: 0.6191 - val_loss: 1.2392 - val_precision: 0.6208 - val_recall: 0.6172
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.9938 - loss: 0.0128 - precision: 0.9939 - recall: 0.9937 - val_accuracy: 0.6197 - val_loss: 1.2385 - val_precision: 0.6210 - val_recall: 0.6176
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.9938 - loss: 0.0132 - precision: 0.9939 - recall: 0.9937 - val_accuracy: 0.6205 - val_loss: 1.2342 - val_precision: 0.6218 - val_recall: 0.6186
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.9941 - loss: 0.0128 - precision: 0.9941 - recall: 0.9940 - val_accuracy: 0.6199 - val_loss: 1.2440 - val_precision: 0.6211 - val_recall: 0.6181
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - accuracy: 0.9944 - loss: 0.0123 - precision: 0.9944 - recall: 0.9944 - val_accuracy: 0.6221 - val_loss: 1.2512 - val_precision: 0.6236 - val_recall: 0.6205
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - accuracy: 0.9937 - loss: 0.0129 - precision: 0.9938 - recall: 0.9937 - val_accuracy: 0.6180 - val_loss: 1.2870 - val_precision: 0.6193 - val_recall: 0.6165
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.9939 - loss: 0.0128 - precision: 0.9939 - recall: 0.9939 - val_accuracy: 0.6175 - val_loss: 1.2823 - val_precision: 0.6189 - val_recall: 0.6160
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.9940 - loss: 0.0127 - precision: 0.9941 - recall: 0.9940 - val_accuracy: 0.6190 - val_loss: 1.2827 - val_precision: 0.6203 - val_recall: 0.6175

# %%
X_test = X_test.astype(float)
y_test = y_test.astype(float)

# %%
# predicting target attribute on testing dataset
test_results = model.evaluate(X_test, y_test,verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')
# Out:
# 705/705 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7872 - loss: 1.0508 - precision: 0.7876 - recall: 0.7868
# Test results - Loss: 1.0515161752700806 - Accuracy: 78.5397469997406%

# %%
results = model.evaluate(X_test, y_test,batch_size = 128)
# Out:
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7873 - loss: 1.0498 - precision: 0.7876 - recall: 0.7868

# %%
print(model.metrics_names)
print(results)
# Out:
# ['loss', 'compile_metrics']
# [1.051515817642212, 0.785397469997406, 0.7856920957565308, 0.7848207950592041]

# %%
# # Plot of accuracy vs epoch for train and test dataset
# plt.plot(history.history['accuracy'])
# plt.plot(history.history['val_accuracy'])
# plt.title("Plot of accuracy vs epoch for train and test dataset")
# plt.ylabel('accuracy')
# plt.xlabel('epoch')
# plt.show()
pd.DataFrame(history.history)
pd.DataFrame(history.history)[['accuracy','val_accuracy']].plot()
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
# Out:
# Text(0.5, 0, 'Epochs')

# %%
# # Plot of loss vs epoch for train and test dataset
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title("Plot of loss vs epoch for train and test dataset")
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper right')
# plt.show()
pd.DataFrame(history.history)
pd.DataFrame(history.history)[['loss','val_loss']].plot()
plt.ylabel('Model Loss')
plt.xlabel('Epochs')
# Out:
# Text(0.5, 0, 'Epochs')

# %%
from sklearn.metrics import classification_report

y_predict = model.predict(X_test)
y_pred = y_predict.argmax(axis=-1)
y_test = y_test.argmax(axis = -1 )
report = classification_report(y_test, y_pred)
print(report)
print(y_pred)
df1 = pd.DataFrame(y_pred)
# saving the dataframe
df1.to_csv('/content/drive/MyDrive/DLC-IDS/Outputs/CD.csv', index = False)
# Out:
# 705/705 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.86      0.42      0.57      5373
#            1       0.89      0.89      0.89      7460
#            2       0.71      0.91      0.80      9711
#
#     accuracy                           0.79     22544
#    macro avg       0.82      0.74      0.75     22544
# weighted avg       0.80      0.79      0.77     22544
#
# [1 1 2 ... 1 2 0]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)
# create a ConfusionMatrixDisplay object
cm_display = ConfusionMatrixDisplay(cm)
# plot the confusion matrix
print("Confusion Matrix:\n", cm)
cm_display.plot()
plt.show()
# Out:
# Confusion Matrix:
#  [[2270  244 2859]
#  [  61 6626  773]
#  [ 315  586 8810]]

# %%
import numpy as np


def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):

    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

# %%
from sklearn.metrics import confusion_matrix
plot_confusion_matrix(cm=confusion_matrix(y_test, y_pred),
                      normalize=False,
                      target_names=[],
                      title="Confusion Matrix")

# %%
from sklearn.metrics import confusion_matrix
plot_confusion_matrix(cm=confusion_matrix(y_test, y_pred),
                      normalize=True,
                      target_names=[],
                      title="Confusion Matrix")

# %%
model.save("NSL-KDD LSTM.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
